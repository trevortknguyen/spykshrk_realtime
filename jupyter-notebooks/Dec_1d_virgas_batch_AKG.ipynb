# %%
# import packages
import os 
path_main = '/home/anna/Src/spykshrk_realtime/'
os.chdir(path_main)  # navigate to main spykshrk parent directory 

# %load_ext autoreload
# %autoreload 2

#from Dec_1d_classifier_virgas_AKG import main
from Dec_1d_v2_virgas_AKG import main

# %%
rat_name = 'despereaux'
dayepstring =  '17_4'
# define data source filepaths on virga
path_base = '/stelmo/anna/'
output_dir = path_base + rat_name + '/filterframework/decoding/'
shift_amt = 0

# %%
# iterate through dayep pairs
dayeplist = dayepstring.split(',')
days, eps = zip(*[f.split('_') for f in dayeplist ])
for day, ep in zip(days, eps):
    main(path_base, rat_name, int(day), int(ep), shift_amt, output_dir,dec_all_flag=1)
# Out:
# 2020-03-05 15:28:38.759075
# despereaux
# Shift amount is:  0
# Day:  17 Epoch:  4
# Tetrodes:  [2, 3, 4, 6, 8, 16, 18, 19, 20, 22, 23, 24, 25, 26, 27]
# Velocity thresh:  4
# Duplicate marks found (and removed): 0
# original length: 3986728
# deadchans pre-stripped; replacing nans with zeros
# subbing zeros for c03 on tet 3
# deadchans pre-stripped; replacing nans with zeros
# subbing zeros for c01 on tet 16
# subbing zeros for c02 on tet 16
# subbing zeros for c03 on tet 16
# deadchans pre-stripped; replacing nans with zeros
# subbing zeros for c02 on tet 18
# subbing zeros for c03 on tet 18
# deadchans pre-stripped; replacing nans with zeros
# subbing zeros for c03 on tet 19
# deadchans pre-stripped; replacing nans with zeros
# subbing zeros for c03 on tet 27
# 7 above 2000uV events removed
# 0 below 100uV events removed
# 0 below -999uV events removed
# after filtering: 3986721
# Rips less than velocity thresh: 2148
# ...

# %%
# %debug
