# %%
# import packages
import os 
path_main = '/home/anna/Src/spykshrk_realtime/'
os.chdir(path_main)  # navigate to main spykshrk parent directory 

# %load_ext autoreload
# %autoreload 2

from Dec_1d_classifier_virgas_AKG import main

# %%
rat_name = 'roquefort'
dayepstring =  '15_2,15_4,16_2,16_4,17_2,17_4,18_2,18_4'
# define data source filepaths on virga
path_base = '/stelmo/anna/'
output_dir = path_base + rat_name + '/filterframework/decoding/'
shift_amt = 0

# %%
# iterate through dayep pairs
dayeplist = dayepstring.split(',')
days, eps = zip(*[f.split('_') for f in dayeplist ])
for day, ep in zip(days, eps):
    main(path_base, rat_name, int(day), int(ep), shift_amt, output_dir)
# Out:
# 2019-11-06 15:55:17.939235
# roquefort
# Shift amount is:  0
# Day:  15 Epoch:  2
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/computation/scope.py in resolve(self, key, is_local)
#     180             if self.has_resolvers:
# --> 181                 return self.resolvers[key]
#     182
#
# ~/anaconda3/lib/python3.6/collections/__init__.py in __getitem__(self, key)
#     882                 pass
# --> 883         return self.__missing__(key)            # support subclasses that define __missing__
#     884
#
# ~/anaconda3/lib/python3.6/collections/__init__.py in __missing__(self, key)
#     874     def __missing__(self, key):
# --> 875         raise KeyError(key)
#     876
#
# KeyError: 'day'
#
# During handling of the above exception, another exception occurred:
#
# ...

# %%
# %debug
